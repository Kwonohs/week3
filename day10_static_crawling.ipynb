# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import json

# %% [markdown]
# # Crawling
#
# 스크레이핑(Scraping)이라고도 하며 웹 페이지 내의 데이터를 추출하는 것을 의미 <br>
# 데이터를 수집하기 위한 방법으로 많이 사용 <br>
# 크게 두 가지의 방법이 존재
# 1. 정적크롤링 <br>
# 정적 데이터를 수집하는 방법 <br>
# 정적 데이터란 페이지 내에 원하는 정보가 모두 들어남
#
# 2. 동적크롤링 <br>
# 동적 데이터를 수집하는 방법 <br>
# 동적 데이터란 클릭, 로그인 등의 행위를 통해 원하는 데이터에 접근 가능 <br>
#
#
# |    |정적 크롤링|동적 크롤링|
# |----|--------|--------|
# |방법 |주소 사용  |브라우저 사용|
# |수집 범위|제한적  |제한 없음|
# |속도|매우 빠름|매우
# <br>
#
# 크롤링 시 사이트에서 크롤링을 허용하는지를 반드시 확인해야 함 <br>
# robots.txt를 뒤에 붙여 확인 가능 <br>
# 강제는 아니나 이를 무시하면 추후 법률적 문제가 생길 수 있음
# ```
# www.daum.net/robots.txt
# User-agent: *
# Disallow: /
# ```
# *: All <br>
# /: All Directories

# %%
# robots.txt 를 사용했을때, Disallow : /가 있으면 크롤링 하지말란 뜻이다.

# %% [markdown]
# ## HTTP
#
# WWW(World Wide Web, W3) 상에서 정보를 주고받을 수 있는 프로토콜 <br>
# 클라이언트와 서버 사이에 이루어지는 요청/응답 프로토콜

# %% [markdown]
# ### API
# API(Application Programming Interface) <br>
# - Application: 고유한 기능을 가진 모든 소프트웨어
# - Interface: 두 애플리케이션 간의 규약 <br>
# 이 계약은 요청과 응답을 사용하여 두 애플리케이션이 서로 통신하는 방법을 정의합니다.

# %% [markdown]
# ### REST
# REST(Representational State Transfer): 자원을 이름으로 구분하여 해당 자원의 상태를 주고받는 것 <br>
#
# REST 구성
# 1. 자원(Resource): HTTP URI
# 2. 자원에 대한 행위(Verb): HTTP Method
# 3. 자원에 대한 행위의 내용(Representations): HTTP Message Pay Load
#
#
# - HTTP URI(Uniform Resource Identifier)를 통해 자원(Resource)을 명시
# - HTTP Method(POST, GET, PUT, DELETE)를 사용하여 URI에 대한 CRUD Operation을 적용 <br>
# <br>
#
# HTTP Methods
# - GET: 자원 검색
# - POST: 자원 작성
# - PUT: 자원 업데이트
# - DELETE: 데이터 삭제
# - HEAD: 자원 검색 (GET과 유사하나 상태 줄과 헤더만 반환)
# - OPTIONS: 자원이 지원하고 있는 메소드의 취득
# - PATCH: 자원 일부 수정 (PUT과 유사하나 일부만 수정)
# - CONNECT: 자원의 터널 접속을 변경
# - TRACE: 리소스에 대한 경로를 따라 메시지 루프백 테스트를 수행
# <br>
#
# HTTP Status
# 1. 1xx(Informational): 요청 처리중
# 2. 2xx(Successful): 요청 정상 처리 <br>
# 200: 요청 성공
# 3. 3xx(Redirection): 요청을 완료하려면 추가 행동이 필요
# 4. 4xx(Client Error): 클라이언트 오류, 잘못된 문법등으로 요청을 수행할 수 없음 <br>
# 400: Bad Request, 클라이언트의 잘못된 요청으로 서버가 요청을 처리할 수 없음 <br>
# 401: Unauthorized, 해당 리소스에 대한 인증이 필요함 <br>
# 403: Forbidden, 서버가 요청을 이해했지만 승인을 거부함 <br>
# 404: Not Found, 리소스를 찾을 수 없음 <br>
# 5. 5xx(Server Error): 서버 오류

# %% [markdown]
# ### REST API
# REST의 원리를 따르는 API <br>
# ※ RESTful: REST의 원리를 따르는 시스템

# %% [markdown]
# ## HTML
# HTML(HyperText Markup Language)은 웹 페이지 표시를 위해 개발된 지배적인 마크업 언어 <br>
# HTML은 웹 페이지 콘텐츠 안의 꺾쇠 괄호에 둘러싸인 "태그"로 되어있는 HTML 요소 형태로 작성 <br>
# HTML은 웹 브라우저와 같은 HTML 처리 장치의 행동에 영향을 주는 자바스크립트, 본문과 그 밖의 항목의 외관과 배치를 정의하는 CSS 같은 스크립트를 포함하거나 불러올 수 있음 <br>
# <br>
# HTML 선택자: HTML에서는 다수의 동일한 태그가 존재하는데 각 태그를 구별할 수 있도록 선택자를 이용
# ```html
# <div>
# 	<div>
#       <a> c </a>
#       <span> c++ </span>
#     </div>
#
#     <div>
#       <a> java </a>
#       <span> python </span>
#     </div>
# </div>
# ```
#
# ```html
# <div id="contents">
# 	<div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = requests.get("https://jsonplaceholder.typicode.com/users/1") #requests를 통해서 가지고 온 데이터는 문자열이다.

# import json
# json.loads(response.text) 딕셔너리로 바꿔주는 함수.

# %%
bs = BeautifulSoup(response.text, 'lxml')
bs
# Out:
# <html><body><p>{
#   "id": 1,
#   "name": "Leanne Graham",
#   "username": "Bret",
#   "email": "Sincere@april.biz",
#   "address": {
#     "street": "Kulas Light",
#     "suite": "Apt. 556",
#     "city": "Gwenborough",
#     "zipcode": "92998-3874",
#     "geo": {
#       "lat": "-37.3159",
#       "lng": "81.1496"
#     }
#   },
#   "phone": "1-770-736-8031 x56442",
#   "website": "hildegard.org",
#   "company": {
#     "name": "Romaguera-Crona",
#     "catchPhrase": "Multi-layered client-server neural-net",
#     "bs": "harness real-time e-markets"
#   }
# }</p></body></html>

# %% [markdown]
# ## 정적크롤링

# %% [markdown]
# ### 라이브러리

# %% [markdown]
# #### requests
#
# requests: 파이썬용 http 라이브러리 <br>
# reference: https://requests.readthedocs.io/en/latest/
#
# 메소드별 사용법
# ```python
# GET: requests.get()
# POST: requests.post()
# PUT: requests.put()
# DELETE: requests.delete()
# ```
#
# ```python
# import requests
#
# requests.get("https://jsonplaceholder.typicode.com/users/1")
# ```

# %%
# Out:
# {'id': 1,
#  'name': 'Leanne Graham',
#  'username': 'Bret',
#  'email': 'Sincere@april.biz',
#  'address': {'street': 'Kulas Light',
#   'suite': 'Apt. 556',
#   'city': 'Gwenborough',
#   'zipcode': '92998-3874',
#   'geo': {'lat': '-37.3159', 'lng': '81.1496'}},
#  'phone': '1-770-736-8031 x56442',
#  'website': 'hildegard.org',
#  'company': {'name': 'Romaguera-Crona',
#   'catchPhrase': 'Multi-layered client-server neural-net',
#   'bs': 'harness real-time e-markets'}}

# %% [markdown]
# ##### Response Body
#
# 요청이 정상적으로 처리가 되면, response body에 요청한 데이터가 담겨져 옴. <br>
# response body 크게 3가지 방식으로 읽을 수 있음 <br>
# 1. content: binary 원문을 읽음
# ```python
# response.content
# ```
# 2. text: utf-8로 인코딩 된 문자열로 읽음
# ```python
# response.text
# ```
# 3. json: 응답이 json이면 dict로 읽음
# ```python
# response.json()
# ```

# %% [markdown]
# ##### Request
#
# param: 주소에 포함된 변수를 담음<br>
# ex) https://www.naver.com/post/12345 <br>
# -> 12345 <br>
# query: 주소 바깥? 이후의 주소를 담음<br>
# ex) https://www.naver.com/post/post_id=12345&id=1 <br>
# -> 12345, 1
# body: XML, JSON 등의 데이터를 담음, 주소에서는 확인 불가<br>
# <br>
#
# requests에서는 아래와 같이 사용
# - get
# ```python
# response = requests.get("https://naver.com/post", params={"post_id": "12345", "id": "1"})
# ```
#
# - post, put: HTML 데이터 전송
# ```python
# response = requests.get("https://naver.com/post", data={"post_id": "12345", "id": "1"})
# ```
# json 형태로도 요청 가능
# ```python
# response = requests.get("https://naver.com/post", json={"post_id": "12345", "id": "1"})
# ```

# %% [markdown]
# ##### headers
#
# 일부 웹 사이트는 bot agent를 차단 <br>
# 이 경우 header의 user-agent를 아래와 같이 넘기면 해결 <br>
# ```python
# requests.get("https://naver.com/post", headers={'User-Agent': 'Mozilla 5.0'})
# ```

# %% [markdown]
# #### BeautifulSoup
#
# BeautifulSoup: html, xml 등으로부터 원하는 정보를 가지고 올 수 있도록 하는 라이브러리 <br>
# reference: https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# ```python
# import requests
# from bs4 import BeautifulSoup
#
# response = requests.get(url)
# bs = BeautifulSoup(response.text, 'lxml')
# ```

# %% [markdown]
# ###### Parser
#
# |parser|특징|설치|속도|사용방법|
# |------|---|---|---|------|
# |html.parser||기본|보통|BeautifulSoup(html_doc, 'html.parser')|
# |lxml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'lxml')|
# |xml|xml 지원|lxml 필요|빠름|BeautifulSoup(html_doc, 'xml')|
# |html5lib|브라우저와 동일|html5lib 필요|느림|BeautifulSoup(html_doc, 'html5lib')|

# %% [markdown]
# ##### find
# 속성과 값을 이용하여 원하는 값을 찾음
#
# find: 매칭되는 값 중 상위 1개 반환
# find_all: 매칭되는 전체 반환
#
# 특정 태그 추출
# ```python
# soup.find_all('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.find_all(class_='a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.find_all('p', attrs={'class': 'a'}) # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.find_all(id='b') # b id를 갖는 값 추출
# ```
# <br>

# %% [markdown]
# ##### select
# CSS Selector로 태그를 찾아 반환 <br>
# CSS에서 HTML을 태깅하는 방법을 활용 <br>
# <br>
# select_one: 매칭되는 값 중 상위 1개 반환 <br>
# select: 매칭되는 전체 반환 <br>
# <br>
#
# 특정 태그 추출
# ```python
# soup.select('p') # p 태그 추출
# ```
# <br>
#
# 특정 클래스 추출
# ```python
# soup.select('.a') # a 클래스 추출
# ```
# <br>
#
# 특정 태그와 class 추출
# ```python
# soup.select('p.a') # p 태그와 a 클래스 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 id 추출
# ```python
# soup.select('#b') # b id를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 id 추출
# ```python
# soup.select('p#b') # p 태그와 b id 모두를 갖는 값 추출
# ```
# <br>
#
# 특정 태그와 class, id 모두 추출
# ```python
# soup.select('p.a#b') # p 태그와 a 클래스 b id 모두 갖는 값 추출
# ```
# <br>
#
# 특정 태그 아래에 있는 태그 찾기
# ```python
# soup.select('div p') # div 아래 p태그가 있는 값 추출
# soup.select('div > p') # div 바로 아래 p태그가 있는 값 추출
# soup.select("div > #link") # div 바로 아래 link id가 있는 값 추출
# ```
# <br>
#
# 형제 태그 찾기
# ```python
# soup.select("#link + .sister") # link 태그와 형제 태그 중 바로 직후 1개
# soup.select("#link ~ .sister") # link 태그와 형제 태그 중 뒤에 태그 전부
# ```
# <br>
#
# 여러 태그 중 i번째 태그 추출
# ```python
# soup.select('a:nth-of-type(i)') # 추출된 a태그 중 i번째 값 반환
# ```
# <br>
# <br>
#
# 정규표현식 활용 <br>
# ```python
# soup.select('[class~=a]') # class 속성 중 a를 포함하는 태그
# soup.select('a[href]') # a 태그 중 href 속성이 존재하는 태그
# soup.select('a[href="https://www.naver.com"]') # a 태그 중 href 속성이 https://www.naver.com과 매칭되는 태그
# soup.select('a[href^="https://"]') # a 태그 중 href 속성이 https://로 시작하는 태그
# soup.select('a[href$="ac.kr"]') # a 태그 중 href 속성이 ac.kr로 끝나는 태그
# soup.select('a[href*="naver"]') # a 태그 중 href 속성 중 naver를 가지는 태그
# ```
#
# <br>
# <br>
#
# 출력
# ```python
# soup.strings # 값 반환
# soup.stripped_strings # 공백을 제거한 값 반환
# ```

# %%
bs.select('p')
# Out:
# [<p>{
#    "id": 1,
#    "name": "Leanne Graham",
#    "username": "Bret",
#    "email": "Sincere@april.biz",
#    "address": {
#      "street": "Kulas Light",
#      "suite": "Apt. 556",
#      "city": "Gwenborough",
#      "zipcode": "92998-3874",
#      "geo": {
#        "lat": "-37.3159",
#        "lng": "81.1496"
#      }
#    },
#    "phone": "1-770-736-8031 x56442",
#    "website": "hildegard.org",
#    "company": {
#      "name": "Romaguera-Crona",
#      "catchPhrase": "Multi-layered client-server neural-net",
#      "bs": "harness real-time e-markets"
#    }
#  }</p>]

# %%
'''
<div> 
	<div> 
      <a> c </a> 
      <span> c++ </span> 
    </div> 
    
    <div> 
      <a> java </a> 
      <span> python </span> 
    </div> 
</div>
'''

# %%
response = '''
<div> 
	<div> 
      <a> c </a> 
      <span> c++ </span> 
    </div> 
    
    <div> 
      <a> java </a> 
      <span> python </span> 
    </div> 
</div>
'''

# %%
bs4 = BeautifulSoup(response, 'lxml')
languages = bs4.select('a')
languages

languages[0].text.strip()
languages
# Out:
# [<a> c </a>, <a> java </a>]

# %%
[language.text.strip() for language in languages]
# Out:
# ['c', 'java']

# %%
bs4.select('div a')[0]
# Out:
# <a> c </a>

# %% [markdown]
# ### 실습

# %% [markdown]
# ##### 예제
#
# ```html
# <div id="contents">
#     <div class="data1">
#       <span class="language"> c++ </span>
#       <span class="language"> java </span>
#       <span class="language"> python </span>
#   </div>
#
#   <div class="data2">
#       <a class="framework"> tensorflow </a>
#       <a class="framework"> pytorch </a>
#       <a class="framework"> spring </a>
#   </div>
# </div>
# ```

# %%
response = '''
<div id="contents"> 
	<div class="data1"> 
      <span class="language"> c++ </span> 
      <span class="language"> java </span> 
      <span class="language"> python </span> 
  </div> 
    
  <div class="data2"> 
      <a class="framework"> tensorflow </a> 
      <a class="framework"> pytorch </a> 
      <a class="framework"> spring </a> 
  </div> 
</div>
'''

# %%
bs4 = BeautifulSoup(response, 'lxml')
languages = bs4.select('div span') #language = bs4.select('.language'), language = bs4.select('span.language') 이런식으로 가져올 수 있다.
languages = bs4.select('a.framework')
[language.text.strip() for language in languages]
# Out:
# ['tensorflow', 'pytorch', 'spring']

# %%
bs4.select('#contents')
# #은 id, .은 class정보를 가져올 수 있다.
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>]

# %%
bs4.select('div#contents')
bs4.select('div#contents.data1')
bs4.select('div#contents')
# Out:
# [<div id="contents">
#  <div class="data1">
#  <span class="language"> c++ </span>
#  <span class="language"> java </span>
#  <span class="language"> python </span>
#  </div>
#  <div class="data2">
#  <a class="framework"> tensorflow </a>
#  <a class="framework"> pytorch </a>
#  <a class="framework"> spring </a>
#  </div>
#  </div>]

# %% [markdown]
# #### 네이버 뉴스

# %%
response = requests.get('https://n.news.naver.com/mnews/article/009/0005351727')
if response.status_code == 200:
    bs = BeautifulSoup(response.text, 'lxml')

# %%
times = bs.select('div.media_end_head_info_datestamp_bunch > span')
times
# Out:
# [<span class="media_end_head_info_datestamp_time _ARTICLE_DATE_TIME" data-date-time="2024-08-18 18:05:08" data-date-time-age-in-minutes="1037">2024.08.18. 오후 6:05</span>,
#  <span class="media_end_head_info_datestamp_time _ARTICLE_MODIFY_DATE_TIME" data-modify-date-time="2024-08-18 20:43:16" data-modify-date-time-age-in-minutes="879">2024.08.18. 오후 8:43</span>]

# %%
[time.text for time in times][0].split()
# Out:
# ['2024.08.18.', '오후', '6:05']

# %%
def convert_to_datetime(date: str):
    date, am_pm, time = date.split()

    hour, minute = time.split(':')
    hour = int(hour)

    if am_pm == '오후' and hour != 12:
        hour += 12
    time = f'{hour}:{minute}'
    datetime_ = f'{date}{time}'

    return pd.to_datetime(datetime_, format = '%Y.%m.%d.%H:%M')
convert_to_datetime(times[0].text)
# Out:
# Timestamp('2024-08-18 18:05:00')

# %%
posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
print(posting_time, modifying_time)
# Out:
# 2024-08-18 18:05:00 2024-08-18 20:43:00

# %%
title = bs.select('h2#title_area span')
title = title[0].text
title
# Out:
# '인구 비상사태, 기업 대응 낙제점'

# %%
reporter = reporter[0].text
reporter = reporter.split()[0]
reporter
# Out:
# '성승훈'

# %%
content = bs.select('article#dic_area')
content = content[0]
content.text
# Out:
# '\n한미연 EPG 경영 평가, 300개 기업중 80점이상 5곳 그쳐육아 환경 여전히 팍팍 …"출산장려 기업 인센티브 부족"◆ 기업 인구대응 평가 ◆\n\n\n\n제조업 분야 중견기업에서 근무 중인 30대 여성 직장인 A씨는 수년째 출산을 미루고 있다. 회사에서 자리가 사라질 것 같은 불안감 때문이다. 그는 "주변 사례를 보면 육아휴직 후 돌아올 자리가 없을 것이라는 식으로 압박을 주는 일이 심심치 않게 있었다"며 "경력단절을 막기 위해 출산을 포기하든지 육아를 위해 퇴사하든지 선택지는 둘 중 하나"라고 토로했다.국내 기업들의 인구위기 대응은 \'낙제점\'을 면치 못한 것으로 나타났다. 인구절벽에 직면해 정부가 출산·육아 지원책을 잇달아 내놓고 있지만 현장에서 제대로 작동하지 않고 있다는 지적이다. 18일 매일경제와 한반도미래인구연구원은 국내 최초로 자산 규모 1조원 이상 기업 300곳을 대상으로 EPG(환경·인구·투명경영) 경영평가 점수를 발표했다. 올해 3월 매일경제와 한미연이 제34차 국민보고대회에서 EPG 경영을 제안한 데 따른 후속 조치다. EPG는 ESG에서 \'S(책임·Social)\'를 \'P(인구·Population)\'로 바꾼 용어다. EPG 평가에서 300개 기업 평균 점수는 55.5점에 그쳤다. 최고점은 85.3점이었으며 최저점은 16.2점으로 나타났다. 기초 평가 17개 지표를 기준으로 삼성전기(85.3점)가 1위를 차지했으며 롯데정밀화학(83.8점)과 신한카드·KB국민카드·KT&G(80.9점)가 뒤를 이었다.대부분 기업은 다방면에서 취약점을 노출했다. 남성 육아휴직을 의무화한 기업은 5%인 15곳에 불과했다. 출산·육아휴직 복귀 지원 프로그램을 체계적으로 운영하는 곳도 27곳에 그쳤다.산업계에서는 대부분 출산·양육 지원 제도가 사용자가 아닌 근로자에게만 초점이 맞춰진 점을 지적한다. 정만기 한국산업연합포럼 회장은 "기업이 부담해야 하는 인력난이나 생산성 저하 등에 대한 사업주 지원책은 부족하다"며 "가령 출산을 장려하는 기업에 세금을 깎아주는 인적자본 투자세액공제 도입을 검토할 필요가 있다"고 조언했다.우수 기업에 대한 지원을 강화하기 위해 기업공시 항목에 이를 반영하자는 의견도 제시됐다. 포괄적으로만 공시했던 출산·육아휴직 항목을 상세히 밝히자는 것이다. 출산·육아휴직 사용률, 휴직기간, 복직자 규모, 복직기간 등을 공시할 필요가 있다는 취지다. 일본은 종업원 1000명 이상 기업에 대해 남성 육아휴직 현황을 공시하게 한 이후 남성 육아휴직 사용률이 30%대를 넘어섰다.이인실 한미연 원장은 "시대 변화에 따라 최고디지털책임자(CDO)나 최고인공지능책임자(CAIO) 같은 새 직책이 생겨나듯 기업에 최고인구책임자(CPO)를 만들고 인구위기 대응 전담 부서를 설치하는 방안도 생각할 수 있을 것"이라며 "근본적인 발상의 전환이 필요하다"고 강조했다. [성승훈 기자]\n'

# %%
press_id = '009'
article_id = 'https://n.news.naver.com/mnews/article/009/0005351727'.split('/')[-1]

# %%
# !pip install pymysql    
# !pip install sqlalchemy 
# !pip install pymongo
# Out:
# Requirement already satisfied: pymysql in c:\users\user\anaconda3\lib\site-packages (1.1.1)
# Requirement already satisfied: psycopg2 in c:\users\user\anaconda3\lib\site-packages (2.9.9)
# Requirement already satisfied: sqlalchemy in c:\users\user\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\user\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: pymongo in c:\users\user\anaconda3\lib\site-packages (4.8.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\user\anaconda3\lib\site-packages (from pymongo) (2.6.1)

# %%
# !pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\user\anaconda3\lib\site-packages (2.9.9)

# %%
import psycopg2

# %%
with psycopg2.connect(
    host='localhost',
    dbname='postgres',
    user='postgres',
    password='1',
    port=5432
)as conn:
    with conn.cursor() as cur:
        cur.execute(f'''INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title}', '{content.text.replace('\'', '').replace('\"', '')}')''')

# %%
response = requests.get('https://n.news.naver.com/mnews/article/009/0005351722')
if response.status_code == 200:
    bs = BeautifulSoup(response.text, 'lxml')
    

content = bs.select('article#dic_area')
content = content[0]
content = content.text
reporter = bs.select('em.media_end_head_journalist_name')
reporter[0].text.split()[0]
# Out:
# '김덕식'

# %%
with psycopg2.connect(
    host='localhost',
    dbname='postgres',
    user='postgres',
    password='1',
    port=5432
)as conn:
        with conn.cursor() as cur:
                cur.execute(f'''INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title.replace('\'', '').replace('\"', '')}', '{content.replace('\'', '').replace('\"', '')}')''')
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# Cell In[320], line 9
#       1 with psycopg2.connect(
#       2     host='localhost',
#       3     dbname='postgres',
#    (...)
#       6     port=5432
#       7 )as conn:
#       8         with conn.cursor() as cur:
# ----> 9                 cur.execute(f'''INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title.replace('\'', '').replace('\"', '')}', '{content.replace('\'', '').replace('\"', '')}')''')
#
# UniqueViolation: duplicate key value violates unique constraint "article_pk"
# DETAIL:  Key (press_id, article_id)=(009, 0005352077) already exists.

# %%
response = requests.get('https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009')
bs = BeautifulSoup(response.text, 'lxml') 
bs.select('li dl a')[0].attrs.get('href')
a = [i.attrs.get('href') for i in bs.select('li dl a')]
a
# Out:
# ['https://n.news.naver.com/mnews/article/009/0005351727',
#  'https://n.news.naver.com/mnews/article/009/0005351727',
#  'https://n.news.naver.com/mnews/article/009/0005351728',
#  'https://n.news.naver.com/mnews/article/009/0005351770',
#  'https://n.news.naver.com/mnews/article/009/0005351729',
#  'https://n.news.naver.com/mnews/article/009/0005352099',
#  'https://n.news.naver.com/mnews/article/009/0005352099',
#  'https://n.news.naver.com/mnews/article/009/0005352098',
#  'https://n.news.naver.com/mnews/article/009/0005352098',
#  'https://n.news.naver.com/mnews/article/009/0005352097',
#  'https://n.news.naver.com/mnews/article/009/0005352097',
#  'https://n.news.naver.com/mnews/article/009/0005352096',
#  'https://n.news.naver.com/mnews/article/009/0005352096',
#  'https://n.news.naver.com/mnews/article/009/0005352095',
#  'https://n.news.naver.com/mnews/article/009/0005352095',
#  'https://n.news.naver.com/mnews/article/009/0005352094',
#  'https://n.news.naver.com/mnews/article/009/0005352094',
#  'https://n.news.naver.com/mnews/article/009/0005352093',
#  'https://n.news.naver.com/mnews/article/009/0005352093',
#  'https://n.news.naver.com/mnews/article/009/0005352092',
#  'https://n.news.naver.com/mnews/article/009/0005352092',
#  'https://n.news.naver.com/mnews/article/009/0005352091',
#  'https://n.news.naver.com/mnews/article/009/0005352091',
#  'https://n.news.naver.com/mnews/article/009/0005352090',
#  'https://n.news.naver.com/mnews/article/009/0005352090',
#  'https://n.news.naver.com/mnews/article/009/0005352089',
#  'https://n.news.naver.com/mnews/article/009/0005352089',
#  'https://n.news.naver.com/mnews/article/009/0005352088',
#  'https://n.news.naver.com/mnews/article/009/0005352088',
#  'https://n.news.naver.com/mnews/article/009/0005352087',
#  'https://n.news.naver.com/mnews/article/009/0005352087',
#  'https://n.news.naver.com/mnews/article/009/0005352086',
#  'https://n.news.naver.com/mnews/article/009/0005352086',
#  'https://n.news.naver.com/mnews/article/009/0005352085',
#  'https://n.news.naver.com/mnews/article/009/0005352085',
#  'https://n.news.naver.com/mnews/article/009/0005352084',
#  'https://n.news.naver.com/mnews/article/009/0005352084',
#  'https://n.news.naver.com/mnews/article/009/0005352083',
#  'https://n.news.naver.com/mnews/article/009/0005352083',
#  'https://n.news.naver.com/mnews/article/009/0005352082',
#  'https://n.news.naver.com/mnews/article/009/0005352082',
#  'https://n.news.naver.com/mnews/article/009/0005352081',
#  'https://n.news.naver.com/mnews/article/009/0005352081',
#  'https://n.news.naver.com/mnews/article/009/0005352080',
#  'https://n.news.naver.com/mnews/article/009/0005352080']

# %%
url_with_problem = []
press_id = '009'

for url in list(set([i.attrs.get('href') for i in bs.select('li dl a')])):
    response = requests.get(url)
    if response.status_code == 200:
        bs = BeautifulSoup(response.text, 'lxml')
    else:
        url_with_problem.append(url + 'Link')
        continue
    article_id = url.split('/')[-1]
    press_id = '009'
    times = bs.select('div.media_end_head_info_datestamp_bunch > span')
    if times and len(times) == 2:
        posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
    elif times and len(times) == 1:
        posting_time = [convert_to_datetime(time.text) for time in times][0]
        modifying_time = posting_time
    else:
        url_with_problem.append(url + 'time')
        continue
    title = bs.select('h2#title_area > span')
    if title:
            title = title[0].text
    else:
        url_with_problem.append(url + 'title')
        continue
    reporter = bs.select('em.media_end_head_journalist_name')
    if reporter:
        reporter = reporter[0].text.split()[0]
    else:
        reporter = '아무개'
    content = bs.select('article#dic_area')
    if content:
        content = content[0].text.replace('\'', '').replace('\"', '')
    else:
        url_with_problem.append(url + 'content')
        continue

    with psycopg2.connect(
    host='localhost',
    dbname='postgres',
    user='postgres',
    password='1',
    port=5432
    )as conn:
        with conn.cursor() as cur:
            try:
                cur.execute(f'''INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title.replace('\'', '').replace('\"', '')}', '{content}')''')
            except Exception:
                url_with_problem.append(url + 'INSERT')

# %%
url_with_problem
# Out:
# ['https://n.news.naver.com/mnews/article/009/0005351727INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352081time',
#  'https://n.news.naver.com/mnews/article/009/0005351728INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352080INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351770INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352079time',
#  'https://n.news.naver.com/mnews/article/009/0005352083INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352082INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352087INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352085INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351729INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352076INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352091time',
#  'https://n.news.naver.com/mnews/article/009/0005352093time',
#  'https://n.news.naver.com/mnews/article/009/0005352088INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352089INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352078INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352092INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352090INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352086INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352084time',
#  'https://n.news.naver.com/mnews/article/009/0005352077INSERT']

# %%
response = requests.get('https://m.entertain.naver.com/article/009/0005352079')
bs = BeautifulSoup(response.text, 'lxml') 
bs.select('div.NewsEndMain_info_item__t+40a em.date')
# Out:
# ---------------------------------------------------------------------------
# SelectorSyntaxError                       Traceback (most recent call last)
# Cell In[352], line 3
#       1 response = requests.get('https://m.entertain.naver.com/article/009/0005352079')
#       2 bs = BeautifulSoup(response.text, 'lxml')
# ----> 3 bs.select('div.NewsEndMain_info_item__t+40a em.date')
#
# File c:\Users\USER\anaconda3\Lib\site-packages\bs4\element.py:2116, in Tag.select(self, selector, namespaces, limit, **kwargs)
#    2096 def select(self, selector, namespaces=None, limit=None, **kwargs):
#    2097     """Perform a CSS selection operation on the current element.
#    2098
#    2099     This uses the SoupSieve library.
#    (...)
#    2114     :rtype: bs4.element.ResultSet
#    2115     """
# -> 2116     return self.css.select(selector, namespaces, limit, **kwargs)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\bs4\css.py:162, in CSS.select(self, select, namespaces, limit, flags, **kwargs)
#     158 if limit is None:
#     159     limit = 0
#     161 return self._rs(
# --> 162     self.api.select(
#     163         select, self.tag, self._ns(namespaces, select), limit, flags,
#     164         **kwargs
#     165     )
#     166 )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\__init__.py:147, in select(select, tag, namespaces, limit, flags, custom, **kwargs)
#     135 def select(
#     136     select: str,
#     137     tag: bs4.Tag,
#    (...)
#     143     **kwargs: Any
#     144 ) -> list[bs4.Tag]:
#     145     """Select the specified tags."""
# --> 147     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\__init__.py:65, in compile(pattern, namespaces, flags, custom, **kwargs)
#      62         raise ValueError("Cannot process 'custom' argument on a compiled selector list")
#      63     return pattern
# ---> 65 return cp._cached_css_compile(
#      66     pattern,
#      67     ct.Namespaces(namespaces) if namespaces is not None else namespaces,
#      68     ct.CustomSelectors(custom) if custom is not None else custom,
#      69     flags
#      70 )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\css_parser.py:208, in _cached_css_compile(pattern, namespaces, custom, flags)
#     199 """Cached CSS compile."""
#     201 custom_selectors = process_custom(custom)
#     202 return cm.SoupSieve(
#     203     pattern,
#     204     CSSParser(
#     205         pattern,
#     206         custom=custom_selectors,
#     207         flags=flags
# --> 208     ).process_selectors(),
#     209     namespaces,
#     210     custom,
#     211     flags
#     212 )
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\css_parser.py:1129, in CSSParser.process_selectors(self, index, flags)
#    1126 def process_selectors(self, index: int = 0, flags: int = 0) -> ct.SelectorList:
#    1127     """Process selectors."""
# -> 1129     return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\css_parser.py:965, in CSSParser.parse_selectors(self, iselector, index, flags)
#     963 try:
#     964     while True:
# --> 965         key, m = next(iselector)
#     967         # Handle parts
#     968         if key == "at_rule":
#
# File c:\Users\USER\anaconda3\Lib\site-packages\soupsieve\css_parser.py:1122, in CSSParser.selector_iter(self, pattern)
#    1120         else:
#    1121             msg = f"Invalid character {c!r} position {index}"
# -> 1122         raise SelectorSyntaxError(msg, self.pattern, index)
#    1123 if self.debug:  # pragma: no cover
#    1124     print('## END PARSING')
#
# SelectorSyntaxError: Invalid character '4' position 29
#   line 1:
# div.NewsEndMain_info_item__t+40a em.date
#                              ^

# %%
#전체페이지 crawling
url_with_problem = []
press_id = '009'
for date in pd.date_range('2024-08-17', '2024-08-19'):
    date = date.strftime('%Y%m%d')
    url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date={date}&page=10000'
    response = requests.get(url)
    bs = BeautifulSoup(response.text, 'lxml')
    last_page_num = int(bs.select('div.paging > strong')[0].text)
    for i in range(1, last_page_num + 1):
        url = f'https://news.naver.com/main/list.naver?mode=LPOD&mid=sec&oid=009&date={date}&page={i}'
        response = requests.get(url)
        bs = BeautifulSoup(response.text, 'lxml')
        for asd in list(set([i.attrs.get('href') for i in bs.select('li dl a')])):
            response = requests.get(asd)
            if response.status_code == 200:
                bs = BeautifulSoup(response.text, 'lxml')
            else:
                url_with_problem.append(asd + 'Link')
                continue
            article_id = asd.split('/')[-1]
            times = bs.select('div.media_end_head_info_datestamp_bunch > span')
            if times and len(times) == 2:
                posting_time, modifying_time = [convert_to_datetime(time.text) for time in times]
            elif times and len(times) == 1:
                posting_time = [convert_to_datetime(time.text) for time in times][0]
                modifying_time = posting_time
            else:
                url_with_problem.append(asd + 'time')
                continue
            title = bs.select('h2#title_area > span')
            if title:
                    title = title[0].text
            else:
                url_with_problem.append(asd + 'title')
                continue
            reporter = bs.select('em.media_end_head_journalist_name')
            if reporter:
                reporter = reporter[0].text.split()[0]
            else:
                reporter = '아무개'
            content = bs.select('article#dic_area')
            if content:
                content = content[0].text.replace('\'', '').replace('\"', '')
            else:
                url_with_problem.append(asd + 'content')
                continue

            with psycopg2.connect(
            host='localhost',
            dbname='postgres',
            user='postgres',
            password='1',
            port=5432
            )as conn:
                with conn.cursor() as cur:
                    try:
                        cur.execute(f'''INSERT INTO article VALUES ('{press_id}', '{article_id}', '{posting_time}', '{modifying_time}', '{reporter}', '{title.replace('\'', '').replace('\"', '')}', '{content}')''')
                    except Exception:
                        url_with_problem.append(asd + 'INSERT')

# %%
def crawler(press_id: str, start_date: str, end_date: str, **kwargs): -> list
    with psycopg2.connect(
        host = kwargs.get('host'),
        dbname=kwargs.get('dbname')
        user=kwargs.get('user')
        password=kwargs.get('password')
        port = kwargs.get('port')
    )
# Out:
# 2024-08-17 00:00:00
# 2024-08-18 00:00:00
# 2024-08-19 00:00:00

# %%
# Out:
# ['https://n.news.naver.com/mnews/article/009/0005351727INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352130time',
#  'https://n.news.naver.com/mnews/article/009/0005352123INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352117INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351728INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352132time',
#  'https://n.news.naver.com/mnews/article/009/0005352129time',
#  'https://n.news.naver.com/mnews/article/009/0005352116INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352125time',
#  'https://n.news.naver.com/mnews/article/009/0005352121time',
#  'https://n.news.naver.com/mnews/article/009/0005352124INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352115INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351770INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352131time',
#  'https://n.news.naver.com/mnews/article/009/0005352120time',
#  'https://n.news.naver.com/mnews/article/009/0005352114INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352133time',
#  'https://n.news.naver.com/mnews/article/009/0005351729INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352119time',
#  'https://n.news.naver.com/mnews/article/009/0005352118INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352122INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352126INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352128time',
#  'https://n.news.naver.com/mnews/article/009/0005352127INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352103INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352113INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352101INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352106INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352100time',
#  'https://n.news.naver.com/mnews/article/009/0005352107INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352110INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352105INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352112INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352094INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352096time',
#  'https://n.news.naver.com/mnews/article/009/0005352111INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352098INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352095INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352108INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352104INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352097INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352102INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352109INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352099INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352074INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352081time',
#  'https://n.news.naver.com/mnews/article/009/0005352080INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352079time',
#  'https://n.news.naver.com/mnews/article/009/0005352083INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352082INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352087INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352085INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352075INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352076INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352091time',
#  'https://n.news.naver.com/mnews/article/009/0005352093time',
#  'https://n.news.naver.com/mnews/article/009/0005352088INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352089INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352078INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352092INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352090INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352086INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352084time',
#  'https://n.news.naver.com/mnews/article/009/0005352077INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352068INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352069time',
#  'https://n.news.naver.com/mnews/article/009/0005352059time',
#  'https://n.news.naver.com/mnews/article/009/0005352070INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352063INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352055time',
#  'https://n.news.naver.com/mnews/article/009/0005352061time',
#  'https://n.news.naver.com/mnews/article/009/0005352065time',
#  'https://n.news.naver.com/mnews/article/009/0005352073INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352062time',
#  'https://n.news.naver.com/mnews/article/009/0005352064INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352057INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352066time',
#  'https://n.news.naver.com/mnews/article/009/0005352054time',
#  'https://n.news.naver.com/mnews/article/009/0005352067INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352058INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352056time',
#  'https://n.news.naver.com/mnews/article/009/0005352072time',
#  'https://n.news.naver.com/mnews/article/009/0005352071time',
#  'https://n.news.naver.com/mnews/article/009/0005352060INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352034time',
#  'https://n.news.naver.com/mnews/article/009/0005352053time',
#  'https://n.news.naver.com/mnews/article/009/0005352047INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352045time',
#  'https://n.news.naver.com/mnews/article/009/0005352051INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352050time',
#  'https://n.news.naver.com/mnews/article/009/0005352043time',
#  'https://n.news.naver.com/mnews/article/009/0005352048INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352039time',
#  'https://n.news.naver.com/mnews/article/009/0005352036time',
#  'https://n.news.naver.com/mnews/article/009/0005352037time',
#  'https://n.news.naver.com/mnews/article/009/0005352038time',
#  'https://n.news.naver.com/mnews/article/009/0005352042time',
#  'https://n.news.naver.com/mnews/article/009/0005352052INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352049INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352035time',
#  'https://n.news.naver.com/mnews/article/009/0005352046time',
#  'https://n.news.naver.com/mnews/article/009/0005352041INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352040time',
#  'https://n.news.naver.com/mnews/article/009/0005352044INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352025INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352031time',
#  'https://n.news.naver.com/mnews/article/009/0005352028INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352019INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352027time',
#  'https://n.news.naver.com/mnews/article/009/0005352021time',
#  'https://n.news.naver.com/mnews/article/009/0005352029time',
#  'https://n.news.naver.com/mnews/article/009/0005352018INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352017INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352014INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352016INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352015INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352024INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352026time',
#  'https://n.news.naver.com/mnews/article/009/0005352032time',
#  'https://n.news.naver.com/mnews/article/009/0005352020INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352033INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352022INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352030time',
#  'https://n.news.naver.com/mnews/article/009/0005352023time',
#  'https://n.news.naver.com/mnews/article/009/0005351995INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352001INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352002time',
#  'https://n.news.naver.com/mnews/article/009/0005352011INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352007INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352013INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351998INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352010INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351999INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351994INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352009INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351997INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352012INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352004INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351996INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352008INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352006INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352003INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352000INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005352005time',
#  'https://n.news.naver.com/mnews/article/009/0005351990INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351987INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351976INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351980INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351985INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351978INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351988INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351981INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351979INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351983INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351974INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351992INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351982INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351984INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351975time',
#  'https://n.news.naver.com/mnews/article/009/0005351977INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351989time',
#  'https://n.news.naver.com/mnews/article/009/0005351986INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351991INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351993INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351973INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351963time',
#  'https://n.news.naver.com/mnews/article/009/0005351954INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351960INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351964time',
#  'https://n.news.naver.com/mnews/article/009/0005351955INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351966INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351968INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351956INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351971INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351970INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351969INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351959INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351965time',
#  'https://n.news.naver.com/mnews/article/009/0005351962INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351972time',
#  'https://n.news.naver.com/mnews/article/009/0005351958INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351961INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351967INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351957INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351946time',
#  'https://n.news.naver.com/mnews/article/009/0005351940INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351952INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351943INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351938INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351937INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351939INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351953INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351951INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351944INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351947INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351942INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351941INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351950INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351935INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351948INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351949time',
#  'https://n.news.naver.com/mnews/article/009/0005351934INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351945INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351936INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351929INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351919INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351933time',
#  'https://n.news.naver.com/mnews/article/009/0005351923INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351928INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351918INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351925INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351927INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351914INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351926INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351917INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351916time',
#  'https://n.news.naver.com/mnews/article/009/0005351921time',
#  'https://n.news.naver.com/mnews/article/009/0005351922INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351920INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351930INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351924INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351915INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351931INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351932INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351897INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351907INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351896INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351903INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351895INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351902INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351908INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351911INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351901INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351899INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351894time',
#  'https://n.news.naver.com/mnews/article/009/0005351912time',
#  'https://n.news.naver.com/mnews/article/009/0005351904INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351898INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351900time',
#  'https://n.news.naver.com/mnews/article/009/0005351906INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351909INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351913INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351910INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351905INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351884time',
#  'https://n.news.naver.com/mnews/article/009/0005351876INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351885INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351888INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351893INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351889time',
#  'https://n.news.naver.com/mnews/article/009/0005351879INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351887INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351877time',
#  'https://n.news.naver.com/mnews/article/009/0005351892INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351890time',
#  'https://n.news.naver.com/mnews/article/009/0005351891INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351875INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351882INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351894time',
#  'https://n.news.naver.com/mnews/article/009/0005351883INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351878INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351886INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351880INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351881time',
#  'https://n.news.naver.com/mnews/article/009/0005351860INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351871time',
#  'https://n.news.naver.com/mnews/article/009/0005351866time',
#  'https://n.news.naver.com/mnews/article/009/0005351873time',
#  'https://n.news.naver.com/mnews/article/009/0005351872INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351859time',
#  'https://n.news.naver.com/mnews/article/009/0005351868INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351865INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351856INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351867INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351858INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351874INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351861time',
#  'https://n.news.naver.com/mnews/article/009/0005351870time',
#  'https://n.news.naver.com/mnews/article/009/0005351863time',
#  'https://n.news.naver.com/mnews/article/009/0005351864INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351855INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351869INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351857INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351862INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351845time',
#  'https://n.news.naver.com/mnews/article/009/0005351840INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351853INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351842INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351841INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351850time',
#  'https://n.news.naver.com/mnews/article/009/0005351844time',
#  'https://n.news.naver.com/mnews/article/009/0005351839INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351852INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351847INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351846INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351837INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351836time',
#  'https://n.news.naver.com/mnews/article/009/0005351849time',
#  'https://n.news.naver.com/mnews/article/009/0005351854INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351835INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351834INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351848INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351838time',
#  'https://n.news.naver.com/mnews/article/009/0005351851time',
#  'https://n.news.naver.com/mnews/article/009/0005351833time',
#  'https://n.news.naver.com/mnews/article/009/0005351830INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351832time',
#  'https://n.news.naver.com/mnews/article/009/0005351822time',
#  'https://n.news.naver.com/mnews/article/009/0005351825INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351828INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351827time',
#  'https://n.news.naver.com/mnews/article/009/0005351826INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351819time',
#  'https://n.news.naver.com/mnews/article/009/0005351823INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351824INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351831INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351821INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351818INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351829INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351814INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351816time',
#  'https://n.news.naver.com/mnews/article/009/0005351820time',
#  'https://n.news.naver.com/mnews/article/009/0005351815INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351817time',
#  'https://n.news.naver.com/mnews/article/009/0005351812INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351799INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351813time',
#  'https://n.news.naver.com/mnews/article/009/0005351798INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351805INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351807time',
#  'https://n.news.naver.com/mnews/article/009/0005351809INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351800INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351806time',
#  'https://n.news.naver.com/mnews/article/009/0005351810INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351794INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351796INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351808INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351804INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351801INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351802INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351795INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351811INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351797INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351803INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351792INSERT',
#  'https://n.news.naver.com/mnews/article/009/0005351793INSERT']

# %%
response = requests.get('https://n.news.naver.com/mnews/article/009/0005351722')
if response.status_code == 200:
    bs = BeautifulSoup(response.text, 'lxml')
    

content = bs.select('article#dic_area')
content = content[0]
content = content.text
reporter = bs.select('em.media_end_head_journalist_name')
reporter[0].text.split()[0]
# Out:
# '김덕식'

# %% [markdown]
# #### 네이버 증권

# %% [markdown]
# stock_code = [i.attrs.get('href').split('=') for i in bs.select('tbody tr td a')] #stock_code를 string으로 받음.

# %%
response = requests.get('https://n.news.naver.com/mnews/article/009/0005351722')
if response.status_code == 200:
    bs = BeautifulSoup(response.text, 'lxml')
    

content = bs.select('article#dic_area')
content = content[0]
content = content.text
reporter = bs.select('em.media_end_head_journalist_name')
reporter[0].text.split()[0]
# Out:
# '김덕식'

# %%
url = 'https://finance.naver.com/sise/sise_market_sum.naver?sosok=0'
response = requests.get(url, headers = {'user-agent': 'Mozilla 5.0'})
bs = BeautifulSoup(response.text, 'lxml')
bs.select('tbody tr td a')
url_with_problem = []

url_list = list(set(['https://finance.naver.com' + i.attrs.get('href').replace('board', 'main') for i in bs.select('tbody td a')])) #url정보들을 담은 리스트

for i in url_list:
    stock_code = i.split('=')[-1]
    response = requests.get(i, headers = {'user-agent': 'Mozilla 5.0'})
    if response.status_code == 200:
        bs = BeautifulSoup(response.text, 'lxml')
    else:
        print('연결오류')
        break
    stock_name = bs.select('div#middle h2 a')
    if stock_name:
        stock_name = bs.select('div#middle h2 a')[0].text
    market_price = bs.select('tr td em span.blind')
    if market_price:
        market_price = bs.select('tr td em span.blind')[4].text
    high_price = bs.select('tr td em span.blind')
    if high_price:
        high_price = bs.select('tr td em span.blind')[1].text
    low_price = bs.select('tr td em span.blind')
    if low_price:
        low_price = bs.select('tr td em span.blind')[5].text
    end_price = bs.select('div.rate_info p.no_today span.blind')
    if end_price:
        end_price = end_price[0].text
    trading_amount = bs.select('tr td em span.blind')
    if trading_amount:
        trading_amount = trading_amount[3].text
    total_amount = bs.select('tr.strong td')
    if total_amount:
        total_amount = total_amount[0].text.strip().replace('\n', '').replace('\t', '')
    stock_count = bs.select('div.first em')
    if stock_count:
        stock_count = stock_count[2].text
    face_amount = bs.select('div.first tr td em')
    if face_amount:
        face_amount = face_amount[3].text
    per = bs.select('em#_per')
    if per:
        per = per[0].text
    pbr = bs.select('em#_pbr')
    if pbr:
        pbr = pbr[0].text
    percent = bs.select('em#_dvr')
    if percent:
        percent = percent[0].text
    same_per = bs.select('div.gray em')
    if len(same_per) > 3:
        same_per = same_per[3].text
    with psycopg2.connect(
            host='localhost',
            dbname='postgres',
            user='postgres',
            password='1',
            port=5432
            )as conn:
                with conn.cursor() as cur:
                    try:
                        cur.execute(f'''INSERT INTO naver_finance VALUES ('{stock_code}', '{stock_name}', '{market_price}', '{high_price}', '{low_price}', '{end_price}', '{trading_amount}', '{total_amount}', '{stock_count}', '{face_amount}', '{per}', '{pbr}', '{percent}', '{same_per}')''')
                    except Exception:
                        url_with_problem.append(asd + 'INSERT')

# %%
# bs.select('a=/item/main.naver?code=005930 .title')
response = requests.get('https://finance.naver.com/item/main.naver?code=005930', headers = {'user-agent': 'Mozilla 5.0'})
bs = BeautifulSoup(response.text, 'lxml')
markey_price = bs.select('td em.no_down span.blind')
markey_price

end_price = bs.select('div.rate_info p.no_today span.blind')[0].text
end_price
trading_amount = bs.select('tr td em span.blind')[3].text
trading_amount = bs.select('tr td em span.blind')

total_amount = bs.select('tr.strong td')[0].text.strip().replace('\n', '').replace('\t', '')
stock_count = bs.select('div.first tr td em')[2].text
trading_amount = bs.select('tr.strong td')[0].text.strip().replace('\n', '').replace('\t', '')
trading_amount
total_amount = bs.select('div.first em')[2].text
total_amount
high_price = bs.select('tr td em span.blind')[5].text
high_price

face_amount = bs.select('div.first tr td em')[3].text
face_amount
per = bs.select('em#_per')[0].text
per
pbr = bs.select('em#_pbr')[0].text
pbr
percent = bs.select('em#_dvr')[0].text
percent
same_per = bs.select('div.gray em')[3].text
same_per


#stock_name = bs.select('div#middle h2 a')[0].text
#stock_name
# requests.get(url, headers = {'user-agent': 'Mozilla 5.0'})
# Out:
# '43.09'

# %%
for i in url_list:
    print(i)
# Out:
# https://finance.naver.com/item/main.naver?code=017670
# https://finance.naver.com/item/main.naver?code=042660
# https://finance.naver.com/item/main.naver?code=066570
# https://finance.naver.com/item/main.naver?code=326030
# https://finance.naver.com/item/main.naver?code=005490
# https://finance.naver.com/item/main.naver?code=000810
# https://finance.naver.com/item/main.naver?code=086790
# https://finance.naver.com/item/main.naver?code=003670
# https://finance.naver.com/item/main.naver?code=030200
# https://finance.naver.com/item/main.naver?code=267260
# https://finance.naver.com/item/main.naver?code=010140
# https://finance.naver.com/item/main.naver?code=055550
# https://finance.naver.com/item/main.naver?code=005380
# https://finance.naver.com/item/main.naver?code=024110
# https://finance.naver.com/item/main.naver?code=012450
# https://finance.naver.com/item/main.naver?code=096770
# https://finance.naver.com/item/main.naver?code=105560
# https://finance.naver.com/item/main.naver?code=000270
# https://finance.naver.com/item/main.naver?code=015760
# https://finance.naver.com/item/main.naver?code=042700
# https://finance.naver.com/item/main.naver?code=009150
# https://finance.naver.com/item/main.naver?code=329180
# https://finance.naver.com/item/main.naver?code=373220
# https://finance.naver.com/item/main.naver?code=316140
# https://finance.naver.com/item/main.naver?code=018260
# https://finance.naver.com/item/main.naver?code=035720
# https://finance.naver.com/item/main.naver?code=051910
# https://finance.naver.com/item/main.naver?code=035420
# https://finance.naver.com/item/main.naver?code=009540
# https://finance.naver.com/item/main.naver?code=034020
# https://finance.naver.com/item/main.naver?code=047050
# https://finance.naver.com/item/main.naver?code=000660
# https://finance.naver.com/item/main.naver?code=006400
# https://finance.naver.com/item/main.naver?code=011200
# https://finance.naver.com/item/main.naver?code=259960
# https://finance.naver.com/item/main.naver?code=010130
# https://finance.naver.com/item/main.naver?code=033780
# https://finance.naver.com/item/main.naver?code=032830
# https://finance.naver.com/item/main.naver?code=005930
# https://finance.naver.com/item/main.naver?code=207940
# https://finance.naver.com/item/main.naver?code=012330
# https://finance.naver.com/item/main.naver?code=068270
# https://finance.naver.com/item/main.naver?code=459580
# https://finance.naver.com/item/main.naver?code=005935
# https://finance.naver.com/item/main.naver?code=323410
# https://finance.naver.com/item/main.naver?code=402340
# https://finance.naver.com/item/main.naver?code=138040
# https://finance.naver.com/item/main.naver?code=003550
# https://finance.naver.com/item/main.naver?code=028260
# https://finance.naver.com/item/main.naver?code=034730

# %% [markdown]
# #### 다음 증권

# %%
def crawl_daum_finance(page):
    url = f'https://finance.daum.net/api/trend/market_capitalization?page={page}&perPage=30&fieldName=marketCap&order=desc&market=KOSPI&pagination=true'
    response = requests.get(url, headers = {'user-agent': 'Mozilla 5.0', 'Referer': 'https://finance.daum.net/domestic/market_cap'})
    result = json.loads(response.text).get('data')

    return result

# %%
data =[]
for page in range(1, 77):
    data.extend(crawl_daum_finance(page))

# %%
data[0].get('rank')
# Out:
# 1

# %%
response.text
# Out:
# '{"code":200,"message":"OK","data":[{"rank":1,"rank":1,"code":"KR7005930003","name":"삼성전자","symbolCode":"A005930","tradePrice":79600.000,"change":"RISE","changePrice":1300.000,"changeRate":0.0166028097,"marketCap":475194690980000,"listedShareCount":5969782550,"foreignRatio":"0.5623283582"},{"rank":2,"rank":2,"code":"KR7000660001","name":"SK하이닉스","symbolCode":"A000660","tradePrice":201500.000,"change":"RISE","changePrice":7600.000,"changeRate":0.0391954616,"marketCap":146692476547500,"listedShareCount":728002365,"foreignRatio":"0.5491759563"},{"rank":3,"rank":3,"code":"KR7373220003","name":"LG에너지솔루션","symbolCode":"A373220","tradePrice":329000.000,"change":"FALL","changePrice":500.000,"changeRate":0.0015174507,"marketCap":76986000000000,"listedShareCount":234000000,"foreignRatio":"0.0476472308"},{"rank":4,"rank":4,"code":"KR7207940008","name":"삼성바이오로직스","symbolCode":"A207940","tradePrice":905000.000,"change":"FALL","changePrice":25000.000,"changeRate":0.0268817204,"marketCap":64412470000000,"listedShareCount":71174000,"foreignRatio":"0.1279159384"},{"rank":5,"rank":5,"code":"KR7005380001","name":"현대차","symbolCode":"A005380","tradePrice":258000.000,"change":"RISE","changePrice":3000.000,"changeRate":0.0117647059,"marketCap":54029377278000,"listedShareCount":209416191,"foreignRatio":"0.4101665998"},{"rank":6,"rank":6,"code":"KR7005931001","name":"삼성전자우","symbolCode":"A005935","tradePrice":63800.000,"change":"RISE","changePrice":400.000,"changeRate":0.0063091483,"marketCap":52500171460000,"listedShareCount":822886700,"foreignRatio":"0.760610694"},{"rank":7,"rank":7,"code":"KR7068270008","name":"셀트리온","symbolCode":"A068270","tradePrice":197200.000,"change":"FALL","changePrice":400.000,"changeRate":0.0020242915,"marketCap":42796578668000,"listedShareCount":217021190,"foreignRatio":"0.2271851196"},{"rank":8,"rank":8,"code":"KR7000270009","name":"기아","symbolCode":"A000270","tradePrice":103400.000,"change":"RISE","changePrice":200.000,"changeRate":0.0019379845,"marketCap":41345360317800,"listedShareCount":399858417,"foreignRatio":"0.4131920824"},{"rank":9,"rank":9,"code":"KR7105560007","name":"KB금융","symbolCode":"A105560","tradePrice":88300.000,"change":"RISE","changePrice":1300.000,"changeRate":0.0149425287,"marketCap":35630027657600,"listedShareCount":403511072,"foreignRatio":"0.7632441"},{"rank":10,"rank":10,"code":"KR7055550008","name":"신한지주","symbolCode":"A055550","tradePrice":58100.000,"change":"RISE","changePrice":900.000,"changeRate":0.0157342657,"marketCap":29595745733400,"listedShareCount":509393214,"foreignRatio":"0.6049753207"},{"rank":11,"rank":11,"code":"KR7005490008","name":"POSCO홀딩스","symbolCode":"A005490","tradePrice":321500.000,"change":"FALL","changePrice":1000.000,"changeRate":0.0031007752,"marketCap":27189650445000,"listedShareCount":84571230,"foreignRatio":"0.2820921488"},{"rank":12,"rank":12,"code":"KR7028260008","name":"삼성물산","symbolCode":"A028260","tradePrice":145600.000,"change":"RISE","changePrice":1400.000,"changeRate":0.0097087379,"marketCap":25885365979200,"listedShareCount":177784107,"foreignRatio":"0.2689634063"},{"rank":13,"rank":13,"code":"KR7035420009","name":"NAVER","symbolCode":"A035420","tradePrice":156700.000,"change":"RISE","changePrice":100.000,"changeRate":6.385696E-4,"marketCap":25194932403600,"listedShareCount":160784508,"foreignRatio":"0.4316530297"},{"rank":14,"rank":14,"code":"KR7006400006","name":"삼성SDI","symbolCode":"A006400","tradePrice":308500.000,"change":"FALL","changePrice":500.000,"changeRate":0.001618123,"marketCap":21213857505000,"listedShareCount":68764530,"foreignRatio":"0.383352173"},{"rank":15,"rank":15,"code":"KR7012330007","name":"현대모비스","symbolCode":"A012330","tradePrice":220500.000,"change":"EVEN","changePrice":0.000,"changeRate":0.0,"marketCap":20505418227000,"listedShareCount":92995094,"foreignRatio":"0.4037451481"},{"rank":16,"rank":16,"code":"KR7051910008","name":"LG화학","symbolCode":"A051910","tradePrice":285500.000,"change":"FALL","changePrice":4000.000,"changeRate":0 ...

# %%
for i in range(0,30):
    for j in result['data'][i].keys():
        print(result['data'][i][j])
# Out:
# 1
# KR7005930003
# 삼성전자
# A005930
# 79600.0
# RISE
# 1300.0
# 0.0166028097
# 475194690980000
# 5969782550
# 0.5623283582
# 2
# KR7000660001
# SK하이닉스
# A000660
# 201500.0
# RISE
# 7600.0
# 0.0391954616
# 146692476547500
# 728002365
# 0.5491759563
# 3
# KR7373220003
# LG에너지솔루션
# A373220
# 329000.0
# FALL
# 500.0
# 0.0015174507
# 76986000000000
# 234000000
# 0.0476472308
# 4
# KR7207940008
# 삼성바이오로직스
# A207940
# 905000.0
# FALL
# 25000.0
# 0.0268817204
# 64412470000000
# 71174000
# 0.1279159384
# 5
# KR7005380001
# 현대차
# A005380
# 258000.0
# RISE
# 3000.0
# 0.0117647059
# 54029377278000
# 209416191
# 0.4101665998
# 6
# KR7005931001
# 삼성전자우
# A005935
# 63800.0
# RISE
# 400.0
# 0.0063091483
# 52500171460000
# 822886700
# 0.760610694
# 7
# KR7068270008
# 셀트리온
# A068270
# 197200.0
# FALL
# 400.0
# 0.0020242915
# 42796578668000
# 217021190
# 0.2271851196
# 8
# KR7000270009
# 기아
# A000270
# 103400.0
# RISE
# 200.0
# 0.0019379845
# 41345360317800
# 399858417
# 0.4131920824
# 9
# KR7105560007
# KB금융
# A105560
# 88300.0
# RISE
# 1300.0
# 0.0149425287
# 35630027657600
# 403511072
# 0.7632441
# 10
# KR7055550008
# 신한지주
# A055550
# 58100.0
# RISE
# 900.0
# 0.0157342657
# 29595745733400
# 509393214
# 0.6049753207
# 11
# KR7005490008
# POSCO홀딩스
# A005490
# 321500.0
# FALL
# 1000.0
# 0.0031007752
# 27189650445000
# 84571230
# 0.2820921488
# 12
# KR7028260008
# 삼성물산
# A028260
# 145600.0
# RISE
# 1400.0
# 0.0097087379
# 25885365979200
# 177784107
# 0.2689634063
# 13
# KR7035420009
# NAVER
# A035420
# 156700.0
# RISE
# 100.0
# 0.0006385696
# 25194932403600
# 160784508
# 0.4316530297
# 14
# KR7006400006
# 삼성SDI
# A006400
# 308500.0
# FALL
# 500.0
# 0.001618123
# 21213857505000
# 68764530
# 0.383352173
# 15
# KR7012330007
# 현대모비스
# A012330
# 220500.0
# EVEN
# 0.0
# 0.0
# 20505418227000
# 92995094
# 0.4037451481
# 16
# KR7051910008
# LG화학
# A051910
# 285500.0
# FALL
# 4000.0
# 0.0138169257
# 20154113926500
# 70592343
# 0.3599401425
# 17
# KR7032830002
# 삼성생명
# A032830
# 95800.0
# RISE
# 2200.0
# 0.0235042735
# 19160000000000
# 200000000
# 0.20862103
# 18
# KR7086790003
# 하나금융지주
# A086790
# 63900.0
# RISE
# 1000.0
# 0.0158982512
# 18681586612200
# 292356598
# 0.6943855668
# 19
# KR7329180004
# HD현대중공업
# A329180
# 209500.0
# FALL
# 1500.0
# 0.0071090047
# 18597967802000
# 88773116
# 0.0988614616
# 20
# KR7138040001
# 메리츠금융지주
# A138040
# 92000.0
# RISE
# 1000.0
# 0.010989011
# 17546250488000
# 190720114
# 0.1689468474
# 21
# KR7000810002
# 삼성화재
# A000810
# 349000.0
# RISE
# 2500.0
# 0.0072150072
# 16533818113000
# 47374837
# 0.5405387252
# 22
# KR7035720002
# 카카오
# A035720
# 36450.0
# FALL
# 200.0
# 0.0054570259
# 16165277677350
# 443491843
# 0.2664745719
# 23
# KR7066570003
# LG전자
# A066570
# 97400.0
# EVEN
# 0.0
# 0.0
# 15939297083600
# 163647814
# 0.3234428112
# 24
# KR7259960003
# 크래프톤
# A259960
# 330000.0
# RISE
# 5000.0
# 0.0153846154
# 15805027260000
# 47894022
# 0.4071125829
# 25
# KR7003670007
# 포스코퓨처엠
# A003670
# 201500.0
# RISE
# 1000.0
# 0.0049875312
# 15608838830000
# 77463220
# 0.0950768248
# 26
# KR7012450003
# 한화에어로스페이스
# A012450
# 288000.0
# FALL
# 12000.0
# 0.04
# 14581440000000
# 50630000
# 0.3719600435
# 27
# KR7009540006
# HD한국조선해양
# A009540
# 200500.0
# RISE
# 1200.0
# 0.0060210738
# 14190009758000
# 70773116
# 0.3003892749
# 28
# KR7011200003
# HMM
# A011200
# 17760.0
# FALL
# 160.0
# 0.0089285714
# 13302941448960
# 749039496
# 0.1048307765
# 29
# KR7033780008
# KT&G
# A033780
# 100600.0
# FALL
# 500.0
# 0.0049455984
# 13110443198200
# 130322497
# 0.4509801788
# 30
# KR7003550001
# LG
# A003550
# 79700.0
# FALL
# 300.0
# 0.00375
# 12536889142100
# 157300993
# 0.3539386811

# %%
rank, code, name, symbolCode, tradePrice, change, changePrice, changeRate, marketCap, listedShareCount, foreignRatio

# %%
url = 'https://finance.daum.net/api/trend/market_capitalization?page=1&perPage=30&fieldName=marketCap&order=desc&market=KOSPI&pagination=true'
